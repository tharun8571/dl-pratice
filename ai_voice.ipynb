# %%
# !pip install langchain

# %%
# !pip install gtts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.4.2
#     Uninstalling click-8.4.2:
#       Successfully uninstalled click-8.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wandb 0.28.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# huggingface-hub 1.23.0 requires click<9.0.0,>=8.4.2, but you have click 8.1.8 which is incompatible.
# ...

# %%
pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import io
from gtts import gTTS
from langchain_groq import ChatGroq
import base64
from IPython.display import Audio, display,HTML
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt=ChatPromptTemplate.from_messages([
    ("system", "your the developer your output only code in python"),
    ("user", "{user}")
])

# %%
llm=ChatGroq(model="llama-3.1-8b-instant",api_key="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",temperature=0.7)
llm1=prompt|llm

# %%
while(True):
  buffer_mem=io.BytesIO()
  user=input("enter: ")
  respons=llm1.invoke(user)
  print(llm1.invoke(user))
  audio=gTTS(respons.content)
  audio.write_to_fp(buffer_mem)
  buffer_mem.seek(0)
  read=buffer_mem.read()
  display(Audio(read, autoplay=True))

  if user=="exit":
    print("good bye")
    break
# Out:
# enter: hi
# content='```python\n# A simple "Hello, World!" program in Python\n\ndef hello_world():\n    """\n    Prints "Hello, World!" to the console.\n    """\n    print("Hello, World!")\n\n# Call the function\nhello_world()\n```' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 45, 'total_tokens': 96, 'completion_time': 0.075805386, 'completion_tokens_details': None, 'prompt_time': 0.003872829, 'prompt_tokens_details': None, 'queue_time': 0.05548114, 'total_time': 0.079678215}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_020e283281', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019fe789-d37e-7ef1-a8a4-5ce326939394-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 45, 'output_tokens': 51, 'total_tokens': 96}
#                 <audio  controls="controls" autoplay="autoplay">
# ...
